# %%
# !pwd
# Out:
# /home/jupyter

# %%
# !ls -al /home/jupyter
# Out:
# total 4
# drwxrwxrwx 1 root    root    4096 Dec 18 11:17  .
# drwxr-xr-x 1 root    root    4096 Dec 18 10:51  ..
# drwxr-xr-x 1 jupyter jupyter 4096 Dec 18 11:17  .ipynb_checkpoints
# drwxr-xr-x 1 jupyter jupyter 4096 Dec 18 11:17  .ipython
# drwxr-xr-x 1 jupyter jupyter 4096 Dec 18 11:13  .jupyter
# drwxr-xr-x 1 jupyter jupyter 4096 Dec 18 11:11  .local
# drwxr-xr-x 1 jupyter jupyter 4096 Dec 18 11:11 'Untitled Folder'
# -rw-r--r-- 1 jupyter jupyter   72 Dec 18 11:17  Untitled.ipynb
